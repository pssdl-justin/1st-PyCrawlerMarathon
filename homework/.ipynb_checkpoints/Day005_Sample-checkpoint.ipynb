# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 下載檔案

# %%
import requests
r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
response = r.text

response
# Out:
# '[{"id":232605062,"title":"好像買太小了...","excerpt":"我女友去寵物展幫我買了一個貓咪玩具給斑斑，他說這個五公斤適用，於是今天我拿給了斑斑，他在試尺寸，是不是要再減肥一下","anonymousSchool":false,"anonymousDepartment":true,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2019-12-01T08:27:28.504Z","updatedAt":"2019-12-01T13:13:44.210Z","commentCount":38,"likeCount":3648,"withNickname":false,"tags":[],"topics":["貓"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","gender":"M","school":"中國文化大學","replyTitle":null,"mediaMeta":[{"id":"0054373c-a988-4e7d-a1fb-b74940a63c59","url":"https://i.imgur.com/1NLTEAul.jpg","normalizedUrl":"https://i.imgur.com/1NLTEAul.jpg","thumbnail":"https://i.imgur.com/1NLTEAul.jpg","type":"image/thumbnail","tags":["ANNOTATED"],"createdAt":"2019-12-01T08:27:28.504Z","updatedAt":"2019-12-01T13:13:44.210Z"},{"id":"0054373c-a988-4e7d-a1fb-b74940a63c59","url":"https://i.imgur.com/1NLTEAu.jpg","normalizedUrl":"https://imgur.com/1NLTEAu","thumbnail":"https://i.imgur.com/1NLTEAul.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-12-01T08:27:28.504Z","updatedAt":"2019-12-01T13:13:44.210Z"},{"id":"bf1eef9d-107b-470d-95db-9d9d4985df63","url":"https://i.imgur.com/gKHWE23.jpg","normalizedUrl":"https://imgur.com/gKHWE23","thumbnail":"https://i.imgur.com/gKHWE23l.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-12-01T08:27:28.504Z","updatedAt":"2019-12-01T13:13:44.210Z"},{"id":"6cb28b19-867f-4e8a-923b-9446c26f566d","url":"https://i.imgur.com/PSZ44ou.jpg","normalizedUrl":"https://imgur.com/PSZ44ou","thumbnail":"https://i.imgur.com/PSZ44oul.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-12-01T08:27:28.504Z","updatedAt":"2019-12-01T13:13:44.210Z"},{"id":"4eac4b91-b81d-41e1-9609-f052d3674501","url":"https://i.imgur.com/eYXYw0s.jpg","normalizedUrl":"https://imgur.com/eYXYw0s","thumbnail":"https://i.imgur.com/eYXYw0sl.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-12-01T08:27:28.504Z","updatedAt":"2019-12-01T13:13:44.210Z"},{"id":"8575ee4b-545e-4157-a6a7-e9fe2a70f64d","url":"https://i.imgur.com/qdCbhow.jpg","normalizedUrl":"https://imgur.com/qdCbhow","thumbnail":"https://i.imgur.com/qdCbhowl.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-12-01T08:27:28.504Z","updatedAt":"2019-12-01T13:13:44.210Z"}],"reactions":[{"id":"286f599c-f86a-4932-82f0-f5a06f1eca03","count":3473},{"id":"e8e6bc5d-41b0-4129-b134-97507523d7ff","count":172},{"id":"4b018f48-e184-445f-adf1-fc8e04ba09b9","count":2},{"id":"514c2569-fd53-4d9d-a415-bf0f88e7329f","count":1}],"hidden":false,"customStyle":null,"isSuspiciousAccount":false,"layout":"classic","withImages":true,"withVideos":false,"media":[{"url":"https://i.imgur.com/1NLTEAu.jpg"},{"url":"https://i.imgur.com/gKHWE23.jpg"},{"url":"https://i.imgur.com/PSZ44ou.jpg"},{"url":"https://i.imgur.com/eYXYw0s.jpg"},{"url":"https://i.imgur.com/qdCbhow.jpg"}],"reportReasonText":"","postAvatar":""},{"id":232603660,"title":"我養的是工讀生？🤔","excerpt":"整理我家帥橘的照片，然後翻到以前還不到一歲的照片，有一天抱他起來自拍，結果拍完才發現他的表情有夠好笑，真的很想知道他到底看到什麼，根本就是這個圖啊——>🤯🤯🤯，嘴長那麼開，我都不知道原來我抱著的","anonymousSchool":false,"anonymousDepartment":false,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2019-12-01T02:07:09.729Z","updatedAt":"2019-12-01T02:07:09.729Z","commentCount":27,"likeCount":554,"withNickname":true,"tags":[],"topics":["貓","米克斯","領養代替購買","哈密瓜是麒麟尾","可愛"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","gender":"F","school":"手手","department":"no.787","replyTitle":null,"mediaMeta":[{"id":"3583b0c0-99bc-40db-980f-3be60a7ca0e2","url":"https://i.imgur.com/36Qgbofl.jpg","normalizedUrl":"https://i.imgur.com/36Qgbofl.jpg","thumbnail":"https://i.imgur.com/36Qgbofl.jpg","type":"image/thumbnail","tags":["ANNOTATED"],"createdAt":"2019-12-01T02:07:09.729Z","updatedAt":"2019-12-02T06:54:36.671Z"},{"id":"3583b0c0-99bc-40db-980f-3be60a7ca0e2","url":"https://i.imgur.com/36Qgbof.jpg","normalizedUrl":"https://imgur.com/36Qgbof","thumbnail":"htt ...

# %%
import json
data = json.loads(response)

for d in data:
    print(d['title'])
# Out:
# 好像買太小了...
# 我養的是工讀生？🤔
# 散步好夥伴🐶漆黑寒冷的夜晚也找得到便便💩
# 貓咪沒在尊重男友
# 如果當初這樣做 或許結局就能不同了吧
# 自嗨小橘貓
# 可以幫幫我推上熱門嗎急尋狗啟示
# #圖多 可愛喵喵們(⁎⁍̴̛ᴗ⁍̴̛⁎)
# 你們吸貓，我被貓吸
# #貓 擁有狗靈魂的貓
# 寵物過世碰到的外套
# 兔兔的睡姿⋯⋯
# 我家的紅貴賓到底是不是人轉世？
# 來嘛~~來吸我啊~
# 請問⋯妳是在哈囉？
# 我養了三隻蟲？🐛
# 基隆瑞芳深澳坑走失協找 拜託❗️❗️
# 虎爺公的細漢欸（小弟）
# 送養
# 你有看過這隻狗嗎？
# 中壢/米克斯狗女兒走失
# 淘寶寵物用品開箱&心得📦🐱
# #協尋 玄鳳鸚鵡（已找到愛鳥 謝謝大家 謝謝好心人）
# 睡到投降的傻布偶小貓
# 餵養的浪貓得了乳腺瘤
# 吉娃娃才不吉敗咧
# 她是真的不是假的🌚
# #圖 板橋貓咪走失
# 我的心已融化
# #急#刺蝟

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
#     1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
#     2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
#     3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

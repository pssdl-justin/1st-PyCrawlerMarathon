# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"10986498160","type":"PushEvent","actor":{"id":52700152,"login":"550988293","display_login":"550988293","gravatar_id":"","url":"https://api.github.com/users/550988293","avatar_url":"https://avatars.githubusercontent.com/u/52700152?"},"repo":{"id":196121188,"name":"550988293/550988293.github.io","url":"https://api.github.com/repos/550988293/550988293.github.io"},"payload":{"push_id":4342249507,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"a8a87be3ab157d8e74c9146b86b57b7d519aabf0","before":"ce3fa28e42c2fa5ab6c8782eadd397f9065e1f32","commits":[{"sha":"a8a87be3ab157d8e74c9146b86b57b7d519aabf0","author":{"email":"550988293@qq.com","name":"sws"},"message":"Site updated: 2019-12-02 14:48:50","distinct":true,"url":"https://api.github.com/repos/550988293/550988293.github.io/commits/a8a87be3ab157d8e74c9146b86b57b7d519aabf0"}]},"public":true,"created_at":"2019-12-02T06:49:02Z"},{"id":"10986498161","type":"PushEvent","actor":{"id":45983818,"login":"JacksoNoah","display_login":"JacksoNoah","gravatar_id":"","url":"https://api.github.com/users/JacksoNoah","avatar_url":"https://avatars.githubusercontent.com/u/45983818?"},"repo":{"id":217649573,"name":"Stargon/PlanHub","url":"https://api.github.com/repos/Stargon/PlanHub"},"payload":{"push_id":4342249511,"size":2,"distinct_size":2,"ref":"refs/heads/master","head":"2555f1a389e3f1635878bc7bc0a3de89ddf596e4","before":"10cd4952ab72e65776ea6d285347a2fe7eea7f2f","commits":[{"sha":"e1e244109b5e10c642a13e42b8c0b634da016e69","author":{"email":"45983818+JacksoNoah@users.noreply.github.com","name":"Noah J"},"message":"fixing bug in table, now users are required to input text into each text input box","distinct":true,"url":"https://api.github.com/repos/Stargon/PlanHub/commits/e1e244109b5e10c642a13e42b8c0b634da016e69"},{"sha":"2555f1a389e3f1635878bc7bc0a3de89ddf596e4","author":{"email":"45983818+JacksoNoah@users.noreply.github.com","name":"Noah J"},"message":"Merge pull request #16 from JacksoNoah/master\\n\\nfixing bug in table, now users are required to input text into each t…","distinct":true,"url":"https://api.github.com/repos/Stargon/PlanHub/commits/2555f1a389e3f1635878bc7bc0a3de89ddf596e4"}]},"public":true,"created_at":"2019-12-02T06:49:02Z"},{"id":"10986498147","type":"PushEvent","actor":{"id":31248140,"login":"Jcondori","display_login":"Jcondori","gravatar_id":"","url":"https://api.github.com/users/Jcondori","avatar_url":"https://avatars.githubusercontent.com/u/31248140?"},"repo":{"id":181935387,"name":"Jcondori/Experimentos","url":"https://api.github.com/repos/Jcondori/Experimentos"},"payload":{"push_id":4342249505,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"c1be4e59b9c817049b101b366295426f18c0836b","before":"5d9bd7ef1a5b7a8eeb24f73c2a920ea61fd93014","commits":[{"sha":"c1be4e59b9c817049b101b366295426f18c0836b","author":{"email":"jcondori@vallegrande.edu.pe","name":"Jose Luis Condori Jara"},"message":"Update comando.txt","distinct":true,"url":"https://api.github.com/repos/Jcondori/Experimentos/commits/c1be4e59b9c817049b101b366295426f18c0836b"}]},"public":true,"created_at":"2019-12-02T06:49:02Z"},{"id":"10986498135","type":"ForkEvent","actor":{"id":51992448,"login":"blrdevopstraining","display_login":"blrdevopstraining","gravatar_id":"","url":"https://api.github.com/users/blrdevopstraining","avatar_url":"https://avatars.githubusercontent.com/u/51992448?"},"repo":{"id":42273563,"name":"sclorg/ruby-ex","url":"https://api.github.com/repos/sclorg/ruby-ex"},"payload":{"forkee":{"id":225305096,"node_id":"MDEwOlJlcG9zaXRvcnkyMjUzMDUwOTY=","name":"ruby-ex","full_name":"blrdevopstraining/ruby-ex","private":false,"owner":{"login":"blrdevopstraining","id":51992448,"node_id":"MDQ6VXNlcjUxOTkyNDQ4","avatar_url":"https://avatars0.githubusercontent.com/u/51992448?v=4","gravatar_id":"","url":"https://api.github.com/users/blrdevopstraining","html_url":"https://github.com/blrdevopstraining","followers_url":"https://api.github.com/users/blrdevopstraining/followers","following_url ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '10986498160',
#   'type': 'PushEvent',
#   'actor': {'id': 52700152,
#    'login': '550988293',
#    'display_login': '550988293',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/550988293',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52700152?'},
#   'repo': {'id': 196121188,
#    'name': '550988293/550988293.github.io',
#    'url': 'https://api.github.com/repos/550988293/550988293.github.io'},
#   'payload': {'push_id': 4342249507,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a8a87be3ab157d8e74c9146b86b57b7d519aabf0',
#    'before': 'ce3fa28e42c2fa5ab6c8782eadd397f9065e1f32',
#    'commits': [{'sha': 'a8a87be3ab157d8e74c9146b86b57b7d519aabf0',
#      'author': {'email': '550988293@qq.com', 'name': 'sws'},
#      'message': 'Site updated: 2019-12-02 14:48:50',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/550988293/550988293.github.io/commits/a8a87be3ab157d8e74c9146b86b57b7d519aabf0'}]},
#   'public': True,
#   'created_at': '2019-12-02T06:49:02Z'},
#  {'id': '10986498161',
#   'type': 'PushEvent',
#   'actor': {'id': 45983818,
#    'login': 'JacksoNoah',
#    'display_login': 'JacksoNoah',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JacksoNoah',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45983818?'},
#   'repo': {'id': 217649573,
#    'name': 'Stargon/PlanHub',
#    'url': 'https://api.github.com/repos/Stargon/PlanHub'},
#   'payload': {'push_id': 4342249511,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '2555f1a389e3f1635878bc7bc0a3de89ddf596e4',
#    'before': '10cd4952ab72e65776ea6d285347a2fe7eea7f2f',
#    'commits': [{'sha': 'e1e244109b5e10c642a13e42b8c0b634da016e69',
#      'author': {'email': '45983818+JacksoNoah@users.noreply.github.com',
#       'name': 'Noah J'},
#      'message': 'fixing bug in table, now users are required to input text into each text input box',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Stargon/PlanHub/commits/e1e244109b5e10c642a13e42b8c0b634da016e69'},
#     {'sha': '2555f1a389e3f1635878bc7bc0a3de89ddf596e4',
#      'author': {'email': '45983818+JacksoNoah@users.noreply.github.com',
#       'name': 'Noah J'},
#      'message': 'Merge pull request #16 from JacksoNoah/master\n\nfixing bug in table, now users are required to input text into each t…',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Stargon/PlanHub/commits/2555f1a389e3f1635878bc7bc0a3de89ddf596e4'}]},
#   'public': True,
#   'created_at': '2019-12-02T06:49:02Z'},
#  {'id': '10986498147',
#   'type': 'PushEvent',
#   'actor': {'id': 31248140,
#    'login': 'Jcondori',
#    'display_login': 'Jcondori',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jcondori',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31248140?'},
#   'repo': {'id': 181935387,
#    'name': 'Jcondori/Experimentos',
#    'url': 'https://api.github.com/repos/Jcondori/Experimentos'},
#   'payload': {'push_id': 4342249505,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c1be4e59b9c817049b101b366295426f18c0836b',
#    'before': '5d9bd7ef1a5b7a8eeb24f73c2a920ea61fd93014',
#    'commits': [{'sha': 'c1be4e59b9c817049b101b366295426f18c0836b',
#      'author': {'email': 'jcondori@vallegrande.edu.pe',
#       'name': 'Jose Luis Condori Jara'},
#      'message': 'Update comando.txt',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Jcondori/Experimentos/commits/c1be4e59b9c817049b101b366295426f18c0836b'}]},
#   'public': True,
#   'created_at': '2019-12-02T06:49:02Z'},
#  {'id': '10986498135',
#   'type': 'ForkEvent',
#   'actor': {'id': 51992448,
#    'login': 'blrdevopstraining',
#    'display_login': 'blrdevopstraining',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/blrdevopstraining',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51992448?'},
#   'repo': {'id': 42273563,
#    'name': 'sclorg/ruby-ex',
#    'url': 'https://api.github.com/repos/sclorg/ruby-ex'},
#   'payload': {'forkee': {'id': 225305096,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMjUzMDUwOTY=',
#     'name': 'ruby-ex',
#     'full_name': 'blrdevopstraining/ruby-ex',
#     'private': False,
#     'owner': {'login': 'blrdevopstraining',
#      'id': 51992448,
#      'node_id': 'MDQ6VXNlcjUxOTkyNDQ4',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/51992448?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/blrdevopstraining',
#      'html_url': 'https://github.com/blrdevopstraining',
#      'followers_url': 'https://api.github.com/users/blrdevopstraining/followers',
#      'following_url': 'https://api.github.com/users/blrdevopstraining/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/blrdevopstraining/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/blrdevopstraining/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/blrdevopstraining/subscriptions',
#      'organizations_url': 'https://api.github.com/users/blrdevopstraining/orgs',
#      'repos_url': 'https://api.github.com/users/blrdevopstraining/repos',
#      'events_url': 'https://api.github.com/users/blrdevopstraining/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/blrdevopstraining/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/blrdevopstraining/ruby-ex',
#     'description': None,
#     'fork': True,
#     'url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex',
#     'forks_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/forks',
#     'keys_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/teams',
#     'hooks_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/hooks',
#     'issue_events_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/events',
#     'assignees_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/tags',
#     'blobs_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/languages',
#     'stargazers_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/stargazers',
#     'contributors_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/contributors',
#     'subscribers_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/subscribers',
#     'subscription_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/subscription',
#     'commits_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/merges',
#     'archive_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/downloads',
#     'issues_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/blrdevopstraining/ruby-ex/deployments',
#     'created_at': '2019-12-02T06:49:01Z',
#     'updated_at': '2019-10-03T21:32:05Z',
#     'pushed_at': '2019-10-06T12:38:46Z',
#     'git_url': 'git://github.com/blrdevopstraining/ruby-ex.git',
#     'ssh_url': 'git@github.com:blrdevopstraining/ruby-ex.git',
#     'clone_url': 'https://github.com/blrdevopstraining/ruby-ex.git',
#     'svn_url': 'https://github.com/blrdevopstraining/ruby-ex',
#     'homepage': None,
#     'size': 31,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': False,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2019-12-02T06:49:02Z',
#   'org': {'id': 9047960,
#    'login': 'sclorg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/sclorg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9047960?'}},
#  {'id': '10986498144',
#   'type': 'CreateEvent',
#   'actor': {'id': 46548004,
#    'login': 'ricnsmart',
#    'display_login': 'ricnsmart',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ricnsmart',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46548004?'},
#   'repo': {'id': 186761061,
#    'name': 'ricnsmart/plugins',
#    'url': 'https://api.github.com/repos/ricnsmart/plugins'},
#   'payload': {'ref': 'v0.0.26',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-02T06:49:02Z'},
#  {'id': '10986498126',
#   'type': 'PushEvent',
#   'actor': {'id': 46548004,
#    'login': 'ricnsmart',
#    'display_login': 'ricnsmart',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ricnsmart',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46548004?'},
#   'repo': {'id': 186761061,
#    'name': 'ricnsmart/plugins',
#    'url': 'https://api.github.com/repos/ricnsmart/plugins'},
#   'payload': {'push_id': 4342249500,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b654e3ae679e24359686af476b96c6850b4e6263',
#    'before': 'a1272b632dd115d3b34d418f05f62441bd6e80fa',
#    'commits': [{'sha': 'b654e3ae679e24359686af476b96c6850b4e6263',
#      'author': {'email': 'voson@ricnsmart.com', 'name': 'voson wang'},
#      'message': 'refactor(plugin): 新增GS894C',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ricnsmart/plugins/commits/b654e3ae679e24359686af476b96c6850b4e6263'}]},
#   'public': True,
#   'created_at': '2019-12-02T06:49:02Z'},
#  {'id': '10986498128',
#   'type': 'PushEvent',
#   'actor': {'id': 35332067,
#    'login': 'jacob-zjj',
#    'display_login': 'jacob-zjj',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jacob-zjj',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35332067?'},
#   'repo': {'id': 186265844,
#    'name': 'jacob-zjj/Socket_cplus',
#    'url': 'https://api.github.com/repos/jacob-zjj/Socket_cplus'},
#   'payload': {'push_id': 4342249497,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'be920f589cc6f5b9e3601b34b46857904052c354',
#    'before': 'efda549928a450d342c7377aace763c2556587dc',
#    'commits': [{'sha': 'be920f589cc6f5b9e3601b34b46857904052c354',
#      'author': {'email': '1213608068@qq.com', 'name': 'jacob-zjj'},
#      'message': 'updateReadme',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jacob-zjj/Socket_cplus/commits/be920f589cc6f5b9e3601b34b46857904052c354'}]},
#   'public': True,
#   'created_at': '2019-12-02T06:49:02Z'},
#  {'id': '10986498129',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 4502793,
#    'login': 'liferay-continuous-integration',
#    'display_login': 'liferay-continuous-integration',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/liferay-continuous-integration',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4502793?'},
#   'repo': {'id': 1920851,
#    'name': 'brianchandotcom/liferay-portal',
#    'url': 'https://api.github.com/repos/brianchandotcom/liferay-portal'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/brianchandotcom/liferay-portal/issues/81499',
#     'repository_url': 'https://api.github.com/repos/brianchandotcom/liferay-portal',
#     'labels_url': 'https://api.github.com/repos/brianchandotcom/liferay-portal/issues/81499/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/brianchandotcom/liferay-portal/issues/81499/comments',
#     'events_url': 'https://api.github.com/repos/brianchandotcom/liferay-portal/issues/81499/events',
#     'html_url': 'https://github.com/brianchandotcom/liferay-portal/pull/81499',
#     'id': 530926721,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ3NDY1MTE4',
#     'number': 81499,
#     'title': 'Lps 105094',
#     'user': {'login': 'shuyangzhou',
#      'id': 173369,
#      'node_id': 'MDQ6VXNlcjE3MzM2OQ==',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/173369?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/shuyangzhou',
#      'html_url': 'https://github.com/shuyangzhou',
#      'followers_url': 'https://api.github.com/users/shuyangzhou/followers',
#      'following_url': 'https://api.github.com/users/shuyangzhou/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/shuyangzhou/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/shuyangzhou/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/shuyangzhou/subscriptions',
#      'organizations_url': 'https://api.github.com/users/shuyangzhou/orgs',
#      'repos_url': 'https://api.github.com/users/shuyangzhou/repos',
#      'events_url': 'https://api.github.com/users/shuyangzhou/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/shuyangzhou/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2019-12-02T06:48:57Z',
#     'updated_at': '2019-12-02T06:49:02Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'pull_request': {'url': 'https://api.github.com/repos/brianchandotcom/liferay-portal/pulls/81499',
#      'html_url': 'https://github.com/brianchandotcom/liferay-portal/pull/81499',
#      'diff_url': 'https://github.com/brianchandotcom/liferay-portal/pull/81499.diff',
#      'patch_url': 'https://github.com/brianchandotcom/liferay-portal/pull/81499.patch'},
#     'body': ''},
#    'comment': {'url': 'https://api.github.com/repos/brianchandotcom/liferay-portal/issues/comments/560257580',
#     'html_url': 'https://github.com/brianchandotcom/liferay-portal/pull/81499#issuecomment-560257580',
#     'issue_url': 'https://api.github.com/repos/brianchandotcom/liferay-portal/issues/81499',
#     'id': 560257580,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU2MDI1NzU4MA==',
#     'user': {'login': 'liferay-continuous-integration',
#      'id': 4502793,
#      'node_id': 'MDQ6VXNlcjQ1MDI3OTM=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/4502793?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/liferay-continuous-integration',
#      'html_url': 'https://github.com/liferay-continuous-integration',
#      'followers_url': 'https://api.github.com/users/liferay-continuous-integration/followers',
#      'following_url': 'https://api.github.com/users/liferay-continuous-integration/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/liferay-continuous-integration/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/liferay-continuous-integration/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/liferay-continuous-integration/subscriptions',
#      'organizations_url': 'https://api.github.com/users/liferay-continuous-integration/orgs',
#      'repos_url': 'https://api.github.com/users/liferay-continuous-integration/repos',
#      'events_url': 'https://api.github.com/users/liferay-continuous-integration/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/liferay-continuous-integration/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-12-02T06:49:02Z',
#     'updated_at': '2019-12-02T06:49:02Z',
#     'author_association': 'COLLABORATOR',
#     'body': 'CI is automatically triggering &quot;ci:test:sf&quot; and &quot;ci:test:relevant&quot; for this pull to run Source Formatter and relevant tests.\n\nComment &quot;ci:test&quot; to run the full PR Tester for this pull.'}},
#   'public': True,
#   'created_at': '2019-12-02T06:49:02Z'},
#  {'id': '10986498132',
#   'type': 'CreateEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 78498562,
#    'name': 'prettier/prettier-atom',
#    'url': 'https://api.github.com/repos/prettier/prettier-atom'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/eslint-6.7.2',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'An atom package for the prettier formatter.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-02T06:49:02Z',
#   'org': {'id': 25822731,
#    'login': 'prettier',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/prettier',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25822731?'}},
#  {'id': '10986498133',
#   'type': 'WatchEvent',
#   'actor': {'id': 51020643,
#    'login': 'oOLLMOo',
#    'display_login': 'oOLLMOo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/oOLLMOo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51020643?'},
#   'repo': {'id': 123458551,
#    'name': 'jackfrued/Python-100-Days',
#    'url': 'https://api.github.com/repos/jackfrued/Python-100-Days'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-02T06:49:02Z'},
#  {'id': '10986498121',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 48562208,
#    'login': 'devops-devdocs',
#    'display_login': 'devops-devdocs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/devops-devdocs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48562208?'},
#   'repo': {'id': 17608126,
#    'name': 'magento/devdocs',
#    'url': 'https://api.github.com/repos/magento/devdocs'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/magento/devdocs/issues/6090',
#     'repository_url': 'https://api.github.com/repos/magento/devdocs',
#     'labels_url': 'https://api.github.com/repos/magento/devdocs/issues/6090/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/magento/devdocs/issues/6090/comments',
#     'events_url': 'https://api.github.com/repos/magento/devdocs/issues/6090/events',
#     'html_url': 'https://github.com/magento/devdocs/pull/6090',
#     'id': 530926638,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ3NDY1MDU1',
#     'number': 6090,
#     'title': 'Sample fastly block by coutry code and user agent',
#     'user': {'login': 'michaeldyl520',
#      'id': 4518013,
#      'node_id': 'MDQ6VXNlcjQ1MTgwMTM=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/4518013?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/michaeldyl520',
#      'html_url': 'https://github.com/michaeldyl520',
#      'followers_url': 'https://api.github.com/users/michaeldyl520/followers',
#      'following_url': 'https://api.github.com/users/michaeldyl520/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/michaeldyl520/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/michaeldyl520/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/michaeldyl520/subscriptions',
#      'organizations_url': 'https://api.github.com/users/michaeldyl520/orgs',
#      'repos_url': 'https://api.github.com/users/michaeldyl520/repos',
#      'events_url': 'https://api.github.com/users/michaeldyl520/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/michaeldyl520/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-12-02T06:48:44Z',
#     'updated_at': '2019-12-02T06:49:02Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'pull_request': {'url': 'https://api.github.com/repos/magento/devdocs/pulls/6090',
#      'html_url': 'https://github.com/magento/devdocs/pull/6090',
#      'diff_url': 'https://github.com/magento/devdocs/pull/6090.diff',
#      'patch_url': 'https://github.com/magento/devdocs/pull/6090.patch'},
#     'body': '## Purpose of this pull request\r\n\r\nThis pull request (PR) ...\r\n\r\n## Affected DevDocs pages\r\nhttps://devdocs.magento.com/guides/v2.3/cloud/cdn/fastly-vcl-blacklist.html\r\n<!-- REQUIRED List the affected pages on devdocs.magento.com (URLs). Not needed for large numbers of files. -->\r\n\r\n-  ...\r\n\r\n## Links to Magento source code\r\nhttps://github.com/magento/devdocs/blob/master/src/guides/v2.3/cloud/cdn/fastly-vcl-blacklist.md\r\n<!--  OPTIONAL - REMOVE THIS SECTION IF NOT USED. If this pull request references a file in a Magento codebase repository, add it here. -->\r\n\r\n-  ...\r\n\r\n<!--\r\nIf you are fixing a GitHub issue, note it using GitHub keyword format (https://help.github.com/en/articles/closing-issues-using-keywords#closing-an-issue-in-a-different-repository) to close the issue when this pull request is merged. Example: `Fixes #1234`\r\n\r\n`master` is the default branch. Merged pull requests to `master` go live on the site automatically. Any requested changes to content on the `master` branch must be related to the released codebase. Any content related to future releases goes in the `develop` branch.\r\n\r\nSee Contribution guidelines (https://github.com/magento/devdocs/blob/master/.github/CONTRIBUTING.md) for more information.\r\n-->\r\n'},
#    'comment': {'url': 'https://api.github.com/repos/magento/devdocs/issues/comments/560257581',
#     'html_url': 'https://github.com/magento/devdocs/pull/6090#issuecomment-560257581',
#     'issue_url': 'https://api.github.com/repos/magento/devdocs/issues/6090',
#     'id': 560257581,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU2MDI1NzU4MQ==',
#     'user': {'login': 'devops-devdocs',
#      'id': 48562208,
#      'node_id': 'MDQ6VXNlcjQ4NTYyMjA4',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/48562208?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/devops-devdocs',
#      'html_url': 'https://github.com/devops-devdocs',
#      'followers_url': 'https://api.github.com/users/devops-devdocs/followers',
#      'following_url': 'https://api.github.com/users/devops-devdocs/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/devops-devdocs/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/devops-devdocs/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/devops-devdocs/subscriptions',
#      'organizations_url': 'https://api.github.com/users/devops-devdocs/orgs',
#      'repos_url': 'https://api.github.com/users/devops-devdocs/repos',
#      'events_url': 'https://api.github.com/users/devops-devdocs/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/devops-devdocs/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-12-02T06:49:02Z',
#     'updated_at': '2019-12-02T06:49:02Z',
#     'author_association': 'NONE',
#     'body': 'An admin must run tests on this PR before it can be merged.'}},
#   'public': True,
#   'created_at': '2019-12-02T06:49:02Z',
#   'org': {'id': 168457,
#    'login': 'magento',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/magento',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/168457?'}},
#  {'id': '10986498118',
#   'type': 'PushEvent',
#   'actor': {'id': 55729860,
#    'login': 'aruna355',
#    'display_login': 'aruna355',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aruna355',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55729860?'},
#   'repo': {'id': 215536689,
#    'name': 'lngtechnologies/LNG.ATTENDANCE.PROD.V3',
#    'url': 'https://api.github.com/repos/lngtechnologies/LNG.ATTENDANCE.PROD.V3'},
#   'payload': {'push_id': 4342249494,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/develop',
#    'head': 'dba633c0ac86df40ef30d5540cb961999f08cee3',
#    'before': 'dd0c91e151ac2833e002b39623cca5b108dd1000',
#    'commits': [{'sha': 'dba633c0ac86df40ef30d5540cb961999f08cee3',
#      'author': {'email': 'Admin@192.168.0.113', 'name': 'Aruna'},
#      'message': 'Aruna Commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lngtechnologies/LNG.ATTENDANCE.PROD.V3/commits/dba633c0ac86df40ef30d5540cb961999f08cee3'}]},
#   'public': True,
#   'created_at': '2019-12-02T06:49:02Z'},
#  {'id': '10986498106',
#   'type': 'MemberEvent',
#   'actor': {'id': 11530201,
#    'login': 'funoy',
#    'display_login': 'funoy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/funoy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11530201?'},
#   'repo': {'id': 224576232,
#    'name': 'ideacome-frontend/react-native-echarts',
#    'url': 'https://api.github.com/repos/ideacome-frontend/react-native-echarts'},
#   'payload': {'member': {'login': 'woow-wu',
#     'id': 26397969,
#     'node_id': 'MDQ6VXNlcjI2Mzk3OTY5',
#     'avatar_url': 'https://avatars2.githubusercontent.com/u/26397969?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/woow-wu',
#     'html_url': 'https://github.com/woow-wu',
#     'followers_url': 'https://api.github.com/users/woow-wu/followers',
#     'following_url': 'https://api.github.com/users/woow-wu/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/woow-wu/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/woow-wu/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/woow-wu/subscriptions',
#     'organizations_url': 'https://api.github.com/users/woow-wu/orgs',
#     'repos_url': 'https://api.github.com/users/woow-wu/repos',
#     'events_url': 'https://api.github.com/users/woow-wu/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/woow-wu/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'action': 'added'},
#   'public': True,
#   'created_at': '2019-12-02T06:49:02Z',
#   'org': {'id': 37863723,
#    'login': 'ideacome-frontend',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ideacome-frontend',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37863723?'}},
#  {'id': '10986498108',
#   'type': 'CreateEvent',
#   'actor': {'id': 8710175,
#    'login': 'terribleherbst',
#    'display_login': 'terribleherbst',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/terribleherbst',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8710175?'},
#   'repo': {'id': 176119645,
#    'name': 'nifty10m/yangying',
#    'url': 'https://api.github.com/repos/nifty10m/yangying'},
#   'payload': {'ref': 'comparison-detector',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'A snapshot testing library for spock test',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-02T06:49:02Z',
#   'org': {'id': 40202384,
#    'login': 'nifty10m',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/nifty10m',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40202384?'}},
#  {'id': '10986498095',
#   'type': 'PushEvent',
#   'actor': {'id': 58139068,
#    'login': 'toddmnortonCO',
#    'display_login': 'toddmnortonCO',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/toddmnortonCO',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58139068?'},
#   'repo': {'id': 224488676,
#    'name': 'toddmnortonCO/learn-co-sandbox',
#    'url': 'https://api.github.com/repos/toddmnortonCO/learn-co-sandbox'},
#   'payload': {'push_id': 4342249484,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': 'a37997d010829e491d5e75c1b1dbbb62aaa4e793',
#    'before': '17a7d90377636f677d09840f9ad9b1d06a630e76',
#    'commits': [{'sha': 'a37997d010829e491d5e75c1b1dbbb62aaa4e793',
#      'author': {'email': 'toddmnorton@live.com',
#       'name': 'inherited-snippet-0885'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/toddmnortonCO/learn-co-sandbox/commits/a37997d010829e491d5e75c1b1dbbb62aaa4e793'}]},
#   'public': True,
#   'created_at': '2019-12-02T06:49:02Z'},
#  {'id': '10986498105',
#   'type': 'PushEvent',
#   'actor': {'id': 206310,
#    'login': 'mikhuang',
#    'display_login': 'mikhuang',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mikhuang',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/206310?'},
#   'repo': {'id': 207001349,
#    'name': 'mikhuang/yang-prints',
#    'url': 'https://api.github.com/repos/mikhuang/yang-prints'},
#   'payload': {'push_id': 4342249485,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd3e1039874a17844b944845b1e44f12167d9f6d8',
#    'before': '7fa64c1313fe7ef2c9820c73a7bc14f06e0c44b8',
#    'commits': [{'sha': 'd3e1039874a17844b944845b1e44f12167d9f6d8',
#      'author': {'email': 'mike@standard.ai', 'name': 'Michael Huang'},
#      'message': 'adding THE CLAW',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mikhuang/yang-prints/commits/d3e1039874a17844b944845b1e44f12167d9f6d8'}]},
#   'public': True,
#   'created_at': '2019-12-02T06:49:02Z'},
#  {'id': '10986498097',
#   'type': 'ForkEvent',
#   'actor': {'id': 51982494,
#    'login': 'wrightway12',
#    'display_login': 'wrightway12',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wrightway12',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51982494?'},
#   'repo': {'id': 95310221,
#    'name': 'vanyasem/VK-Scraper',
#    'url': 'https://api.github.com/repos/vanyasem/VK-Scraper'},
#   'payload': {'forkee': {'id': 225305095,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMjUzMDUwOTU=',
#     'name': 'VK-Scraper',
#     'full_name': 'wrightway12/VK-Scraper',
#     'private': False,
#     'owner': {'login': 'wrightway12',
#      'id': 51982494,
#      'node_id': 'MDQ6VXNlcjUxOTgyNDk0',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/51982494?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/wrightway12',
#      'html_url': 'https://github.com/wrightway12',
#      'followers_url': 'https://api.github.com/users/wrightway12/followers',
#      'following_url': 'https://api.github.com/users/wrightway12/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/wrightway12/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/wrightway12/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/wrightway12/subscriptions',
#      'organizations_url': 'https://api.github.com/users/wrightway12/orgs',
#      'repos_url': 'https://api.github.com/users/wrightway12/repos',
#      'events_url': 'https://api.github.com/users/wrightway12/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/wrightway12/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/wrightway12/VK-Scraper',
#     'description': "Scrapes VK user's photos",
#     'fork': True,
#     'url': 'https://api.github.com/repos/wrightway12/VK-Scraper',
#     'forks_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/forks',
#     'keys_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/teams',
#     'hooks_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/hooks',
#     'issue_events_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/events',
#     'assignees_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/tags',
#     'blobs_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/languages',
#     'stargazers_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/stargazers',
#     'contributors_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/contributors',
#     'subscribers_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/subscribers',
#     'subscription_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/subscription',
#     'commits_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/merges',
#     'archive_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/downloads',
#     'issues_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/wrightway12/VK-Scraper/deployments',
#     'created_at': '2019-12-02T06:49:01Z',
#     'updated_at': '2019-11-27T16:35:34Z',
#     'pushed_at': '2019-09-19T03:14:20Z',
#     'git_url': 'git://github.com/wrightway12/VK-Scraper.git',
#     'ssh_url': 'git@github.com:wrightway12/VK-Scraper.git',
#     'clone_url': 'https://github.com/wrightway12/VK-Scraper.git',
#     'svn_url': 'https://github.com/wrightway12/VK-Scraper',
#     'homepage': '',
#     'size': 112,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'gpl-3.0',
#      'name': 'GNU General Public License v3.0',
#      'spdx_id': 'GPL-3.0',
#      'url': 'https://api.github.com/licenses/gpl-3.0',
#      'node_id': 'MDc6TGljZW5zZTk='},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2019-12-02T06:49:02Z'},
#  {'id': '10986498104',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 122179801,
#    'name': 'DFE-Digital/teacher-vacancy-service',
#    'url': 'https://api.github.com/repos/DFE-Digital/teacher-vacancy-service'},
#   'payload': {'action': 'opened',
#    'number': 1179,
#    'pull_request': {'url': 'https://api.github.com/repos/DFE-Digital/teacher-vacancy-service/pulls/1179',
#     'id': 347465139,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ3NDY1MTM5',
#     'html_url': 'https://github.com/DFE-Digital/teacher-vacancy-service/pull/1179',
#     'diff_url': 'https://github.com/DFE-Digital/teacher-vacancy-service/pull/1179.diff',
#     'patch_url': 'https://github.com/DFE-Digital/teacher-vacancy-service/pull/1179.patch',
#     'issue_url': 'https://api.github.com/repos/DFE-Digital/teacher-vacancy-service/issues/1179',
#     'number': 1179,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump bullet from 5.9.0 to 6.0.2',
#     'user': {'login': 'dependabot-preview[bot]',
#      'id': 27856297,
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/2141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [bullet](https://github.com/flyerhzm/bullet) from 5.9.0 to 6.0.2.\n<details>\n<summary>Changelog</summary>\n\n*Sourced from [bullet\'s changelog](https://github.com/flyerhzm/bullet/blob/master/CHANGELOG.md).*\n\n> ## 6.0.2 (08/20/2019)\n> \n> * Fully support Rails 6.0\n> \n> ## 6.0.1 (06/26/2019)\n> \n> * Add Bullet::ActiveJob\n> * Prevent "Maximum call stack exceeded" errors when used with Turbolinks\n> \n> ## 6.0.0 (04/25/2019)\n> \n> * Add XHR support to Bullet\n> * Support Rails 6.0\n> * Handle case where ID is manually set on unpersisted record\n</details>\n<details>\n<summary>Commits</summary>\n\n- [`007cc1b`](https://github.com/flyerhzm/bullet/commit/007cc1b819ca37b932b6aba31a32196978c85077) Bumping version to 6.0.2\n- [`aa310ee`](https://github.com/flyerhzm/bullet/commit/aa310eef11c5d5f104081fdefa97dd90b5a9f67a) support rails 6\n- [`f09d280`](https://github.com/flyerhzm/bullet/commit/f09d280ac7da9781e1f0a11df3dd74b343fea0ed) Merge pull request [#466](https://github-redirect.dependabot.com/flyerhzm/bullet/issues/466) from santib/fix-readme\n- [`b362ab2`](https://github.com/flyerhzm/bullet/commit/b362ab29583109822b940906b6bd2eb501763096) Fix README to prevent issues on production\n- [`c00e202`](https://github.com/flyerhzm/bullet/commit/c00e2021c4105be51b972d5b39e89832ed97668c) Bumping version to 6.0.1\n- [`5caf958`](https://github.com/flyerhzm/bullet/commit/5caf958cf48f2d2f0e03ec268f8a9260c77a968e) update README\n- [`fe0ffb6`](https://github.com/flyerhzm/bullet/commit/fe0ffb699928e2aae83bde0bf7bee94842768942) Merge pull request [#465](https://github-redirect.dependabot.com/flyerhzm/bullet/issues/465) from janklimo/454-turbolinks\n- [`c83f4e6`](https://github.com/flyerhzm/bullet/commit/c83f4e67e687d333c6e8b7371a119bc2cac4d24f) Prevent "Maximum call stack exceeded" errors when used with Turbolinks\n- [`3d3aa3a`](https://github.com/flyerhzm/bullet/commit/3d3aa3a175b2adb5b96b9ed02bc779e3f9a16c4f) Auto corrected by following Lint Javascript unicorn/prefer-add-event-listener\n- [`8be261c`](https://github.com/flyerhzm/bullet/commit/8be261c6233057565ba0181b1dcbcaad99acc782) Auto corrected by following Lint Ruby Lint/UnneededCopEnableDirective\n- Additional commits viewable in [compare view](https://github.com/flyerhzm/bullet/compare/5.9.0...6.0.2)\n</details>\n<br />\n\n[![Dependabot compatibility score](https://api.dependabot.com/badges/compatibility_score?dependency-name=bullet&package-manager=bundler&previous-version=5.9.0&new-version=6.0.2)](https://dependabot.com/compatibility-score.html?dependency-name=bullet&package-manager=bundler&previous-version=5.9.0&new-version=6.0.2)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this  ...
#     'created_at': '2019-12-02T06:49:01Z',
#     'updated_at': '2019-12-02T06:49:01Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/DFE-Digital/teacher-vacancy-service/pulls/1179/commits',
#     'review_comments_url': 'https://api.github.com/repos/DFE-Digital/teacher-vacancy-service/pulls/1179/comments',
#     'review_comment_url': 'https://api.github.com/repos/DFE-Digital/teacher-vacancy-service/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/DFE-Digital/teacher-vacancy-service/issues/1179/comments',
#     'statuses_url': 'https://api.github.com/repos/DFE-Digital/teacher-vacancy-service/statuses/75e8d17409625eacce22f062f7e1853a88e1af64',
#     'head': {'label': 'DFE-Digital:dependabot/bundler/bullet-6.0.2',
#      'ref': 'dependabot/bundler/bullet-6.0.2',
#      'sha': '75e8d17409625eacce22f062f7e1853a88e1af64',
#      'user': {'login': 'DFE-Digital',
#       'id': 30029772,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMwMDI5Nzcy',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/30029772?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/DFE-Digital',
#       'html_url': 'https://github.com/DFE-Digital',
#       'followers_url': 'https://api.github.com/users/DFE-Digital/followers',
#       'following_url': 'https://api.github.com/users/DFE-Digital/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/DFE-Digital/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/DFE-Digital/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/DFE-Digital/subscriptions',
#       'organizations_url': 'https://api.github.com/users/DFE-Digital/orgs',
#       'repos_url': 'https://api.github.com/users/DFE-Digital/repos',
#       'events_url': 'https://api.github.com/users/DFE-Digital/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/DFE-Digital/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 122179801,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMjIxNzk4MDE=',
#       'name': 'teacher-vacancy-service',
#       'full_name': 'DFE-Digital/teacher-vacancy-service',
#       'private': False,
#       'owner': {'login': 'DFE-Digital',
#        'id': 30029772,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMwMDI5Nzcy',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/30029772?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/DFE-Digital',
#        'html_url': 'https://github.com/DFE-Digital',
#        'followers_url': 'https://api.github.com/users/DFE-Digital/followers',
#        'following_url': 'https://api.github.com/users/DFE-Digital/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/DFE-Digital/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/DFE-Digital/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/DFE-Digital/subscriptions',
#        'organizations_url': 'https://api.github.com/users/DFE-Digital/orgs',
#        'repos_url': 'https://api.github.com/users/DFE-Digital/repos',
#        'events_url': 'https://api.github.com/users/DFE-Digital/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/DFE-Digital/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/DFE-Digital/teacher-vacancy-service',
#       'description': "Department for Education's Teaching Vacancies Beta",
#       'fork': False,
#       'url': 'https://api.github.com/repos/DFE-Digital/teacher-vacancy-service',
#       'forks_url': 'https://api.github.com/repos/DFE-Digital/teacher-vacancy-service/forks',
#       'keys_url': 'https://api.github.com/repos/DFE-Digital/teacher-vacancy-service/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/DFE-Digital/teacher-vacancy-service/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/DFE-Digital/teacher-vacancy-service/teams',
#       'hooks_url': 'https://api.github.com/repos/DFE-Digital/teacher-vacancy-service/hooks',
#       'issue_events_url': 'https://api.github.com/repos/DFE-Digital/teacher-vacancy-service/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/DFE-Digital/teacher-vacancy-service/events',
#       'assignees_url': 'https://api.github.com/repos/DFE-Digital/teacher-vacancy-service/assignees{/user}',
# ...
#      'sha': 'd2e7fc906edb0c7ea50aa89e946b53cdbd822c0b',
#      'user': {'login': 'jubaaitidir',
#       'id': 48445165,
#       'node_id': 'MDQ6VXNlcjQ4NDQ1MTY1',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/48445165?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jubaaitidir',
#       'html_url': 'https://github.com/jubaaitidir',
#       'followers_url': 'https://api.github.com/users/jubaaitidir/followers',
#       'following_url': 'https://api.github.com/users/jubaaitidir/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jubaaitidir/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jubaaitidir/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jubaaitidir/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jubaaitidir/orgs',
#       'repos_url': 'https://api.github.com/users/jubaaitidir/repos',
#       'events_url': 'https://api.github.com/users/jubaaitidir/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jubaaitidir/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 193483327,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTM0ODMzMjc=',
#       'name': 'IPSSI_Symfony',
#       'full_name': 'jubaaitidir/IPSSI_Symfony',
#       'private': False,
#       'owner': {'login': 'jubaaitidir',
#        'id': 48445165,
#        'node_id': 'MDQ6VXNlcjQ4NDQ1MTY1',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/48445165?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/jubaaitidir',
#        'html_url': 'https://github.com/jubaaitidir',
#        'followers_url': 'https://api.github.com/users/jubaaitidir/followers',
#        'following_url': 'https://api.github.com/users/jubaaitidir/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/jubaaitidir/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/jubaaitidir/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/jubaaitidir/subscriptions',
#        'organizations_url': 'https://api.github.com/users/jubaaitidir/orgs',
#        'repos_url': 'https://api.github.com/users/jubaaitidir/repos',
#        'events_url': 'https://api.github.com/users/jubaaitidir/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/jubaaitidir/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/jubaaitidir/IPSSI_Symfony',
#       'description': None,
#       'fork': True,
#       'url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony',
#       'forks_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/forks',
#       'keys_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/teams',
#       'hooks_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/hooks',
#       'issue_events_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/events',
#       'assignees_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/tags',
#       'blobs_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/languages',
#       'stargazers_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/stargazers',
#       'contributors_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/contributors',
#       'subscribers_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/subscribers',
#       'subscription_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/subscription',
#       'commits_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/merges',
#       'archive_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/downloads',
#       'issues_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/deployments',
#       'created_at': '2019-06-24T10:22:18Z',
#       'updated_at': '2019-06-25T14:53:52Z',
#       'pushed_at': '2019-12-02T06:48:57Z',
#       'git_url': 'git://github.com/jubaaitidir/IPSSI_Symfony.git',
#       'ssh_url': 'git@github.com:jubaaitidir/IPSSI_Symfony.git',
#       'clone_url': 'https://github.com/jubaaitidir/IPSSI_Symfony.git',
#       'svn_url': 'https://github.com/jubaaitidir/IPSSI_Symfony',
#       'homepage': None,
#       'size': 675,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'PHP',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 10,
#       'license': None,
#       'forks': 0,
#       'open_issues': 10,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'jubaaitidir:feature-break-code',
#      'ref': 'feature-break-code',
#      'sha': 'e93d9a21062c6f831e565819926a6723f53c10bb',
#      'user': {'login': 'jubaaitidir',
#       'id': 48445165,
#       'node_id': 'MDQ6VXNlcjQ4NDQ1MTY1',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/48445165?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jubaaitidir',
#       'html_url': 'https://github.com/jubaaitidir',
#       'followers_url': 'https://api.github.com/users/jubaaitidir/followers',
#       'following_url': 'https://api.github.com/users/jubaaitidir/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jubaaitidir/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jubaaitidir/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jubaaitidir/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jubaaitidir/orgs',
#       'repos_url': 'https://api.github.com/users/jubaaitidir/repos',
#       'events_url': 'https://api.github.com/users/jubaaitidir/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jubaaitidir/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 193483327,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTM0ODMzMjc=',
#       'name': 'IPSSI_Symfony',
#       'full_name': 'jubaaitidir/IPSSI_Symfony',
#       'private': False,
#       'owner': {'login': 'jubaaitidir',
#        'id': 48445165,
#        'node_id': 'MDQ6VXNlcjQ4NDQ1MTY1',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/48445165?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/jubaaitidir',
#        'html_url': 'https://github.com/jubaaitidir',
#        'followers_url': 'https://api.github.com/users/jubaaitidir/followers',
#        'following_url': 'https://api.github.com/users/jubaaitidir/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/jubaaitidir/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/jubaaitidir/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/jubaaitidir/subscriptions',
#        'organizations_url': 'https://api.github.com/users/jubaaitidir/orgs',
#        'repos_url': 'https://api.github.com/users/jubaaitidir/repos',
#        'events_url': 'https://api.github.com/users/jubaaitidir/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/jubaaitidir/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/jubaaitidir/IPSSI_Symfony',
#       'description': None,
#       'fork': True,
#       'url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony',
#       'forks_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/forks',
#       'keys_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/teams',
#       'hooks_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/hooks',
#       'issue_events_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/events',
#       'assignees_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/tags',
#       'blobs_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/languages',
#       'stargazers_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/stargazers',
#       'contributors_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/contributors',
#       'subscribers_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/subscribers',
#       'subscription_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/subscription',
#       'commits_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/merges',
#       'archive_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/downloads',
#       'issues_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/deployments',
#       'created_at': '2019-06-24T10:22:18Z',
#       'updated_at': '2019-06-25T14:53:52Z',
#       'pushed_at': '2019-12-02T06:48:57Z',
#       'git_url': 'git://github.com/jubaaitidir/IPSSI_Symfony.git',
#       'ssh_url': 'git@github.com:jubaaitidir/IPSSI_Symfony.git',
#       'clone_url': 'https://github.com/jubaaitidir/IPSSI_Symfony.git',
#       'svn_url': 'https://github.com/jubaaitidir/IPSSI_Symfony',
#       'homepage': None,
#       'size': 675,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'PHP',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 10,
#       'license': None,
#       'forks': 0,
#       'open_issues': 10,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/pulls/50'},
#      'html': {'href': 'https://github.com/jubaaitidir/IPSSI_Symfony/pull/50'},
#      'issue': {'href': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/issues/50'},
#      'comments': {'href': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/issues/50/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/pulls/50/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/pulls/50/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/jubaaitidir/IPSSI_Symfony/statuses/d2e7fc906edb0c7ea50aa89e946b53cdbd822c0b'}},
#     'author_association': 'NONE',
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'unstable',
#     'merged_by': None,
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 108,
#     'deletions': 106,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2019-12-02T06:49:01Z'},
#  {'id': '10986498026',
#   'type': 'CreateEvent',
#   'actor': {'id': 55678680,
#    'login': 'kkaranveer6',
#    'display_login': 'kkaranveer6',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kkaranveer6',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55678680?'},
#   'repo': {'id': 225302352,
#    'name': 'kkaranveer6/start-here-guidelines',
#    'url': 'https://api.github.com/repos/kkaranveer6/start-here-guidelines'},
#   'payload': {'ref': 'contributors',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Guidelines on how this open source community works',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-02T06:49:01Z'}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.19.1'},
#  'origin': '123.195.194.127, 123.195.194.127',
#  'url': 'https://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.19.1'},
#  'json': None,
#  'origin': '123.195.194.127, 123.195.194.127',
#  'url': 'https://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

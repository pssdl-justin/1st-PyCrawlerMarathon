# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？

import requests
import json

r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
response = r.text
data = json.loads(response)

for d in data:
    print(d['title'])
# Out:
# 好像買太小了...
# 我養的是工讀生？🤔
# 散步好夥伴🐶漆黑寒冷的夜晚也找得到便便💩
# 貓咪沒在尊重男友
# 如果當初這樣做 或許結局就能不同了吧
# 自嗨小橘貓
# 可以幫幫我推上熱門嗎急尋狗啟示
# #圖多 可愛喵喵們(⁎⁍̴̛ᴗ⁍̴̛⁎)
# #貓 擁有狗靈魂的貓
# 寵物過世碰到的外套
# 兔兔的睡姿⋯⋯
# 我家的紅貴賓到底是不是人轉世？
# 來嘛~~來吸我啊~
# 請問⋯妳是在哈囉？
# 我養了三隻蟲？🐛
# 基隆瑞芳深澳坑走失協找 拜託❗️❗️
# 你有看過這隻狗嗎？
# 虎爺公的細漢欸（小弟）
# 餵養的浪貓得了乳腺瘤
# 送養
# 中壢/米克斯狗女兒走失
# 淘寶寵物用品開箱&心得📦🐱
# #協尋 玄鳳鸚鵡（已找到愛鳥 謝謝大家 謝謝好心人）
# 睡到投降的傻布偶小貓
# 吉娃娃才不吉敗咧
# 她是真的不是假的🌚
# #圖 板橋貓咪走失
# 我的心已融化
# #急#刺蝟
# 貓咪抽蓄癱軟

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」

CC=[]
LC=[]

for d in data:
    print(d['title'], d['createdAt'], d['commentCount'], d['likeCount'])
    CC.append(d['commentCount'])
    LC.append(d['likeCount'])
# Out:
# 好像買太小了... 2019-12-01T08:27:28.504Z 40 3841
# 我養的是工讀生？🤔 2019-12-01T02:07:09.729Z 27 590
# 散步好夥伴🐶漆黑寒冷的夜晚也找得到便便💩 2019-12-02T02:51:47.393Z 0 300
# 貓咪沒在尊重男友 2019-12-01T10:44:13.896Z 6 118
# 如果當初這樣做 或許結局就能不同了吧 2019-12-01T00:49:18.221Z 0 52
# 自嗨小橘貓 2019-11-30T20:21:16.782Z 2 50
# 可以幫幫我推上熱門嗎急尋狗啟示 2019-12-01T17:56:16.299Z 0 47
# #圖多 可愛喵喵們(⁎⁍̴̛ᴗ⁍̴̛⁎) 2019-12-01T08:44:25.791Z 1 44
# #貓 擁有狗靈魂的貓 2019-12-01T11:43:58.401Z 3 26
# 寵物過世碰到的外套 2019-12-01T09:23:54.879Z 3 22
# 兔兔的睡姿⋯⋯ 2019-12-01T09:01:55.400Z 5 22
# 我家的紅貴賓到底是不是人轉世？ 2019-12-01T06:13:52.856Z 5 18
# 來嘛~~來吸我啊~ 2019-12-01T11:56:53.031Z 1 17
# 請問⋯妳是在哈囉？ 2019-11-30T19:16:39.494Z 2 17
# 我養了三隻蟲？🐛 2019-12-01T12:17:06.699Z 1 15
# 基隆瑞芳深澳坑走失協找 拜託❗️❗️ 2019-12-01T12:22:04.478Z 2 14
# 你有看過這隻狗嗎？ 2019-12-01T20:33:16.869Z 2 12
# 虎爺公的細漢欸（小弟） 2019-11-30T19:16:31.808Z 0 12
# 餵養的浪貓得了乳腺瘤 2019-12-02T05:29:49.540Z 0 11
# 送養 2019-12-02T02:36:37.309Z 1 11
# 中壢/米克斯狗女兒走失 2019-12-01T10:58:09.738Z 0 11
# 淘寶寵物用品開箱&心得📦🐱 2019-12-01T06:19:59.473Z 9 11
# #協尋 玄鳳鸚鵡（已找到愛鳥 謝謝大家 謝謝好心人） 2019-12-01T05:33:55.211Z 2 11
# 睡到投降的傻布偶小貓 2019-12-01T02:10:49.971Z 1 11
# 吉娃娃才不吉敗咧 2019-12-01T09:17:16.567Z 7 10
# 她是真的不是假的🌚 2019-12-01T16:18:44.132Z 0 9
# #圖 板橋貓咪走失 2019-12-02T03:50:17.266Z 3 8
# 我的心已融化 2019-12-01T03:09:54.454Z 2 8
# #急#刺蝟 2019-12-02T05:06:34.886Z 5 7
# 貓咪抽蓄癱軟 2019-11-30T20:03:21.687Z 1 7

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

CC
LC
# Out:
# [3746,
#  572,
#  300,
#  115,
#  52,
#  50,
#  47,
#  43,
#  34,
#  25,
#  22,
#  21,
#  18,
#  17,
#  17,
#  15,
#  14,
#  12,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  9,
#  8,
#  8,
#  7]
